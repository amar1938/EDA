# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"D:\titles.csv")
df
# Out:
#              id                                      title   type  \
# 0      ts300399        Five Came Back: The Reference Films   SHOW
# 1       tm84618                                Taxi Driver  MOVIE
# 2      tm154986                                Deliverance  MOVIE
# 3      tm127384            Monty Python and the Holy Grail  MOVIE
# 4      tm120801                            The Dirty Dozen  MOVIE
# ...         ...                                        ...    ...
# 5845  tm1014599                                  Fine Wine  MOVIE
# 5846   tm898842                                C/O Kaadhal  MOVIE
# 5847  tm1059008                                    Lokillo  MOVIE
# 5848  tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
# 5849   ts271048         Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 0     This collection includes 12 World War II-era p...          1945
# ...

# %%
df.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# id                         0
# title                      1
# type                       0
# description               18
# release_year               0
# age_certification       2619
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 3744
# imdb_id                  403
# imdb_score               482
# imdb_votes               498
# tmdb_popularity           91
# tmdb_score               311
# dtype: int64

# %%
df.head(3)
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm154986                          Deliverance  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  Intent on seeing the Cahulawassee River before...          1972
#
#   age_certification  runtime                                       genres  \
# 0             TV-MA       51                            ['documentation']
# 1                 R      114                           ['drama', 'crime']
# 2                 R      109  ['drama', 'action', 'thriller', 'european']
#
#   production_countries  seasons    imdb_id  imdb_score  imdb_votes  \
# 0               ['US']      1.0        NaN         NaN         NaN
# ...

# %%
df.type
# Out:
# 0        SHOW
# 1       MOVIE
# 2       MOVIE
# 3       MOVIE
# 4       MOVIE
#         ...
# 5845    MOVIE
# 5846    MOVIE
# 5847    MOVIE
# 5848    MOVIE
# 5849     SHOW
# Name: type, Length: 5850, dtype: object

# %%
df.type[1]
# Out:
# 'MOVIE'

# %%
cl = list(df.columns)
for i in cl:
    print("Number of unique values in column",i,"is",df[i].nunique())
# Out:
# Number of unique values in column id is 5850
# Number of unique values in column title is 5798
# Number of unique values in column type is 2
# Number of unique values in column description is 5829
# Number of unique values in column release_year is 63
# Number of unique values in column age_certification is 11
# Number of unique values in column runtime is 202
# Number of unique values in column genres is 1726
# Number of unique values in column production_countries is 452
# Number of unique values in column seasons is 26
# Number of unique values in column imdb_id is 5447
# Number of unique values in column imdb_score is 80
# Number of unique values in column imdb_votes is 3880
# Number of unique values in column tmdb_popularity is 4889
# Number of unique values in column tmdb_score is 394

# %%
df.type.value_counts()
# Out:
# type
# MOVIE    3744
# SHOW     2106
# Name: count, dtype: int64

# %%
df.type.value_counts().plot(kind = 'bar',color = ['skyblue','lightgreen'],edgecolor = 'black',linewidth = 2)
# Out:
# <Axes: xlabel='type'>

# %%
df.type.value_counts().plot(kind = "pie",autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['genres'].value_counts().plot(kind = 'pie',autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df.production_countries.value_counts()
# Out:
# production_countries
# ['US']                1959
# ['IN']                 599
# ['JP']                 264
# []                     229
# ['KR']                 222
#                       ...
# ['CZ', 'GB', 'US']       1
# ['US', 'AU', 'GB']       1
# ['HU']                   1
# ['IQ', 'GB']             1
# ['PH', 'FO']             1
# Name: count, Length: 452, dtype: int64

# %%
df.production_countries.
